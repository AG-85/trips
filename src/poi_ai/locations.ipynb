# %%
import pandas as pd
import pathlib
import math

# %%
appname = "trips"
home_dir = pathlib.Path.home()
bronze = home_dir / "data" / "bronze" / appname
silver = home_dir / "data" / "silver" / appname
gold = home_dir / "data" / "gold" / appname

bronze.mkdir(parents=True, exist_ok=True)
silver.mkdir(parents=True, exist_ok=True)
gold.mkdir(parents=True, exist_ok=True)

# %%
poi = pd.read_csv("/Users/ambikha/PycharmProjects/trips/data/poi.csv")
poi.head()
# Out:
#                       name  latitude_radian  longitude_radian  num_links  \
# 0  YAYCHI, WEST AZERBAIJAN         0.683175          0.778053         13
# 1      MOUNT FISKE GLACIER         0.648196         -2.071114          9
# 2                  ALATONA         0.258356         -0.103606         10
# 3             PEMBA ISLAND        -0.090175          0.694350         43
# 4                    MBOLO         0.149517          0.359829          6
#
#                                                links  num_categories  \
# 0  Baba Jik Rural District; West Azerbaijan Provi...               1
# 1  Mount Fiske; Mount Warlow Glacier; U.S. state;...               3
# 2  Diabaly; Alatona Irrigation Project; Mali; Nio...               2
# 3  Malaysia Airlines Flight 370; Arusha; Chake Ch...               5
# 4  UTC; Sub-prefectures of the Central African Re...               2
#
#                                           categories
# 0               POPULATED PLACES IN CHALDORAN COUNTY
# 1  GLACIERS OF THE SIERRA NEVADA (U.S.); GLACIERS...
# 2  POPULATED PLACES IN SÉGOU REGION; IRRIGATION P...
# 3  PEMBA ISLAND; ISLANDS OF TANZANIA; ISLANDS OF ...
# 4      N'DÉLÉ; POPULATED PLACES IN BAMINGUI-BANGORAN

# %%
lat_min = math.radians(33)
lat_max = math.radians(37.5)
lon_min = math.radians(-116)
lon_max = math.radians(-115.8)


poi["latitude_degree"] = poi["latitude_radian"].apply(math.degrees)
poi["longitude_degree"] = poi["longitude_radian"].apply(math.degrees)

poi_nv = poi[
    (poi["latitude_radian"] >= lat_min)
    & (poi["latitude_radian"] <= lat_max)
    & (poi["longitude_radian"] >= lon_min)
    & (poi["longitude_radian"] <= lon_max)
]

# %%
poi_nv.to_string("/Users/ambikha/PycharmProjects/trips/data/poi.txt", index = False)

# %%
# Approximate latitude and longitude bounds for Nevada in radians including Area 51 in southern Nevada
# Nevada: lat 37.2000°N to 37.3000°N, lon 115.9000°W to 115.7000°W

lat_min = math.radians(33)
lat_max = math.radians(37.5)
lon_min = math.radians(-116)
lon_max = math.radians(-115.8)
"""lat_min = math.radians(37.2000)
lat_max = math.radians(37.3000)
lon_min = math.radians(-115.9000)
lon_max = math.radians(-115.7000)"""


poi["latitude_degree"] = poi["latitude_radian"].apply(math.degrees)
poi["longitude_degree"] = poi["longitude_radian"].apply(math.degrees)

poi_nv = poi[
    (poi["latitude_radian"] >= lat_min)
    & (poi["latitude_radian"] <= lat_max)
    & (poi["longitude_radian"] >= lon_min)
    & (poi["longitude_radian"] <= lon_max)
].head(60)

# %%
print(f"POIs in Nv: {len(poi_nv)} locations\n")

from IPython.display import display

poi_display = poi_nv[["name", "latitude_degree", "longitude_degree"]].copy()

poi_display["latitude_degree"] = poi_display["latitude_degree"].round(5)
poi_display["longitude_degree"] = poi_display["longitude_degree"].round(5)

poi_display = poi_display.rename(
    columns={
        "name": "POI Name",
        "latitude_degree": "Latitude (deg)",
        "longitude_degree": "Longitude (deg)",
    }
)

display(
    poi_display.reset_index(drop=True).style.set_properties(
        **{
            "background-color": "#f5f5f5",
            "border": "1px solid black",
            "text-align": "left",
        }
    )
)

print("\n`First 6 POIs:")
for idx, row in poi_nv.iloc[:6].iterrows():
    print(f"- {row['name']}: ({row['latitude_radian']:.5f}, {row['longitude_radian']:.5f})")
# Out:
# POIs in Nv: 24 locations
# <style type="text/css">
# #T_5306a_row0_col0, #T_5306a_row0_col1, #T_5306a_row0_col2, #T_5306a_row1_col0, #T_5306a_row1_col1, #T_5306a_row1_col2, #T_5306a_row2_col0, #T_5306a_row2_col1, #T_5306a_row2_col2, #T_5306a_row3_col0, #T_5306a_row3_col1, #T_5306a_row3_col2, #T_5306a_row4_col0, #T_5306a_row4_col1, #T_5306a_row4_col2, #T_5306a_row5_col0, #T_5306a_row5_col1, #T_5306a_row5_col2, #T_5306a_row6_col0, #T_5306a_row6_col1, #T_5306a_row6_col2, #T_5306a_row7_col0, #T_5306a_row7_col1, #T_5306a_row7_col2, #T_5306a_row8_col0, #T_5306a_row8_col1, #T_5306a_row8_col2, #T_5306a_row9_col0, #T_5306a_row9_col1, #T_5306a_row9_col2, #T_5306a_row10_col0, #T_5306a_row10_col1, #T_5306a_row10_col2, #T_5306a_row11_col0, #T_5306a_row11_col1, #T_5306a_row11_col2, #T_5306a_row12_col0, #T_5306a_row12_col1, #T_5306a_row12_col2, #T_5306a_row13_col0, #T_5306a_row13_col1, #T_5306a_row13_col2, #T_5306a_row14_col0, #T_5306a_row14_col1, #T_5306a_row14_col2, #T_5306a_row15_col0, #T_5306a_row15_col1, #T_5306a_row15_col2, #T_5306a_row16_col0, #T_5306a_row16_col1, #T_5306a_row16_col2, #T_5306a_row17_col0, #T_5306a_row17_col1, #T_5306a_row17_col2, #T_5306a_row18_col0, #T_5306a_row18_col1, #T_5306a_row18_col2, #T_5306a_row19_col0, #T_5306a_row19_col1, #T_5306a_row19_col2, #T_5306a_row20_col0, #T_5306a_row20_col1, #T_5306a_row20_col2, #T_5306a_row21_col0, #T_5306a_row21_col1, #T_5306a_row21_col2, #T_5306a_row22_col0, #T_5306a_row22_col1, #T_5306a_row22_col2, #T_5306a_row23_col0, #T_5306a_row23_col1, #T_5306a_row23_col2 {
#   background-color: #f5f5f5;
#   border: 1px solid black;
#   text-align: left;
# }
# </style>
# <table id="T_5306a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5306a_level0_col0" class="col_heading level0 col0" >POI Name</th>
#       <th id="T_5306a_level0_col1" class="col_heading level0 col1" >Latitude (deg)</th>
#       <th id="T_5306a_level0_col2" class="col_heading level0 col2" >Longitude (deg)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5306a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5306a_row0_col0" class="data row0 col0" >MOJAVE TRAILS NATIONAL MONUMENT</td>
#       <td id="T_5306a_row0_col1" class="data row0 col1" >34.600000</td>
#       <td id="T_5306a_row0_col2" class="data row0 col2" >-116.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5306a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5306a_row1_col0" class="data row1 col0" >NORTH SHORE, CALIFORNIA</td>
#       <td id="T_5306a_row1_col1" class="data row1 col1" >33.512780</td>
#       <td id="T_5306a_row1_col2" class="data row1 col2" >-115.927220</td>
#     </tr>
#     <tr>
#       <th id="T_5306a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5306a_row2_col0" class="data row2 col0" >SQUEAKY SPRINGS, CALIFORNIA</td>
#       <td id="T_5306a_row2_col1" class="data row2 col1" >33.257780</td>
#       <td id="T_5306a_row2_col2" class="data row2 col2" >-115.948330</td>
#     </tr>
#     <tr>
#       <th id="T_5306a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5306a_row3_col0" class="data row3 col0" >BURIED MOUNTAIN</td>
#       <td id="T_5306a_row3_col1" class="data row3 col1" >33.649420</td>
#       <td id="T_5306a_row3_col2" class="data row3 col2" >-115.856950</td>
#     </tr>
#     <tr>
#       <th id="T_5306a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5306a_row4_col0" class="data row4 col0" >MORTMAR, CALIFORNIA</td>
#       <td id="T_5306a_row4_col1" class="data row4 col1" >33.521670</td>
#       <td id="T_5306a_row4_col2" class="data row4 col2" >-115.935830</td>
#     </tr>
#     <tr>
#       <th id="T_5306a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5306a_row5_col0" class="data row5 col0" >AREA 51</td>
#       <td id="T_5306a_row5_col1" class="data row5 col1" >37.235000</td>
#       <td id="T_5306a_row5_col2" class="data row5 col2" >-115.811110</td>
#     </tr>
#     <tr>
#       <th id="T_5306a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5306a_row6_col0" class="data row6 col0" >CALVADA MEADOWS AIRPORT</td>
#       <td id="T_5306a_row6_col1" class="data row6 col1" >36.271110</td>
#       <td id="T_5306a_row6_col2" class="data row6 col2" >-115.995000</td>
#     </tr>
#     <tr>
#       <th id="T_5306a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5306a_row7_col0" class="data row7 col0" >KANE SPRING, CALIFORNIA</td>
#       <td id="T_5306a_row7_col1" class="data row7 col1" >33.109440</td>
#       <td id="T_5306a_row7_col2" class="data row7 col2" >-115.836670</td>
#     </tr>
#     <tr>
#       <th id="T_5306a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5306a_row8_col0" class="data row8 col0" >HEXIE MOUNTAINS</td>
#       <td id="T_5306a_row8_col1" class="data row8 col1" >33.886680</td>
#       <td id="T_5306a_row8_col2" class="data row8 col2" >-115.955830</td>
#     </tr>
#     <tr>
#       <th id="T_5306a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5306a_row9_col0" class="data row9 col0" >ELMORE DESERT RANCH, CALIFORNIA</td>
#       <td id="T_5306a_row9_col1" class="data row9 col1" >33.103610</td>
#       <td id="T_5306a_row9_col2" class="data row9 col2" >-115.800560</td>
#     </tr>
#     <tr>
#       <th id="T_5306a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5306a_row10_col0" class="data row10 col0" >SALTON SEA AIRPORT</td>
#       <td id="T_5306a_row10_col1" class="data row10 col1" >33.241110</td>
#       <td id="T_5306a_row10_col2" class="data row10 col2" >-115.952500</td>
#     </tr>
#     <tr>
#       <th id="T_5306a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5306a_row11_col0" class="data row11 col0" >SALTON CITY, CALIFORNIA</td>
#       <td id="T_5306a_row11_col1" class="data row11 col1" >33.298610</td>
#       <td id="T_5306a_row11_col2" class="data row11 col2" >-115.956110</td>
#     </tr>
#     <tr>
#       <th id="T_5306a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5306a_row12_col0" class="data row12 col0" >BAGDAD, CALIFORNIA</td>
#       <td id="T_5306a_row12_col1" class="data row12 col1" >34.582780</td>
#       <td id="T_5306a_row12_col2" class="data row12 col2" >-115.875560</td>
#     </tr>
#     <tr>
#       <th id="T_5306a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5306a_row13_col0" class="data row13 col0" >TRUCKHAVEN, CALIFORNIA</td>
#       <td id="T_5306a_row13_col1" class="data row13 col1" >33.296940</td>
#       <td id="T_5306a_row13_col2" class="data row13 col2" >-115.977220</td>
#     </tr>
#     <tr>
#       <th id="T_5306a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5306a_row14_col0" class="data row14 col0" >TWENTYNINE PALMS AIRPORT</td>
#       <td id="T_5306a_row14_col1" class="data row14 col1" >34.131670</td>
#       <td id="T_5306a_row14_col2" class="data row14 col2" >-115.945830</td>
#     </tr>
#     <tr>
#       <th id="T_5306a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5306a_row15_col0" class="data row15 col0" >WONDER VALLEY, CALIFORNIA</td>
#       <td id="T_5306a_row15_col1" class="data row15 col1" >34.151110</td>
#       <td id="T_5306a_row15_col2" class="data row15 col2" >-115.931390</td>
#     </tr>
#     <tr>
#       <th id="T_5306a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5306a_row16_col0" class="data row16 col0" >CACTUS CITY, CALIFORNIA</td>
#       <td id="T_5306a_row16_col1" class="data row16 col1" >33.678330</td>
#       <td id="T_5306a_row16_col2" class="data row16 col2" >-115.963890</td>
#     </tr>
#     <tr>
#       <th id="T_5306a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5306a_row17_col0" class="data row17 col0" >MERCURY, NEVADA</td>
#       <td id="T_5306a_row17_col1" class="data row17 col1" >36.660000</td>
#       <td id="T_5306a_row17_col2" class="data row17 col2" >-115.993060</td>
#     </tr>
#     <tr>
#       <th id="T_5306a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5306a_row18_col0" cla
# `First 6 POIs:
# - MOJAVE TRAILS NATIONAL MONUMENT: (0.60388, -2.02458)
# - NORTH SHORE, CALIFORNIA: (0.58491, -2.02331)
# - SQUEAKY SPRINGS, CALIFORNIA: (0.58046, -2.02368)
# - BURIED MOUNTAIN: (0.58729, -2.02209)
# - MORTMAR, CALIFORNIA: (0.58506, -2.02346)
# - AREA 51: (0.64987, -2.02129)

# %%
import folium

m = folium.Map(location=[37.0, -115.7], zoom_start=6)

# Add a marker for each POI using degree columns
for idx, row in poi_nv.iterrows():
    lat = row["latitude_degree"]
    lon = row["longitude_degree"]
    name = row["name"]

    folium.Marker(
        location=[lat, lon],
        popup=name,
        tooltip=name,
        icon=folium.Icon(color="blue", icon="info-sign"),
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e884a79fed512ed89627d61d238b9872 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e884a79fed512ed89627d61d238b9872&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e884a79fed512ed89627d61d238b9872 = L.map(
#                 &quot;map_e884a79fed512ed89627d61d238b9872&quot;,
#                 {
#                     center: [37.0, -115.7],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6c1b16b155387aa90ba3efa50cdf2359 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6c1b16b155387aa90ba3efa50cdf2359.addTo(map_e884a79fed512ed89627d61d238b9872);
#
#
#             var marker_097ab6f4360ec6f385687cfb7c8777a5 = L.marker(
#                 [34.6, -116.00000000000001],
#                 {
# }
#             ).addTo(map_e884a79fed512ed89627d61d238b9872);
#
#
#             var icon_4fc583413b332f2cb3b21a01a15902c3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9a3fdd25a38648220510918fe2ae81cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc66c5c00f3b09677bbec87391576b0a = $(`&lt;div id=&quot;html_dc66c5c00f3b09677bbec87391576b0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;MOJAVE TRAILS NATIONAL MONUMENT&lt;/div&gt;`)[0];
#                 popup_9a3fdd25a38648220510918fe2ae81cf.setContent(html_dc66c5c00f3b09677bbec87391576b0a);
#
#
#
#         marker_097ab6f4360ec6f385687cfb7c8777a5.bindPopup(popup_9a3fdd25a38648220510918fe2ae81cf)
#         ;
#
#
#
#
#             marker_097ab6f4360ec6f385687cfb7c8777a5.bindTooltip(
#                 `&lt;div&gt;
#                      MOJAVE TRAILS NATIONAL MONUMENT
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_097ab6f4360ec6f385687cfb7c8777a5.setIcon(icon_4fc583413b332f2cb3b21a01a15902c3);
#
#
#             var marker_307b47d550852e62bdd6512b58f8210c = L.marker(
#                 [33.51277777777778, -115.92722222222226],
#                 {
# }
#             ).addTo(map_e884a79fed512ed89627d61d238b9872);
#
#
#             var icon_61ab8305c074ddb0725e44b04352b66c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_de0b3d960422969a357ff70c2e42b8c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_868885d6f6af915c1f306f3084d7a644 = $(`&lt;div id=&quot;html_868885d6f6af915c1f306f3084d7a644&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NORTH SHORE, CALIFORNIA&lt;/div&gt;`)[0];
#                 popup_de0b3d960422969a357ff70c2e42b8c4.setContent(html_868885d6f6af915c1f306f3084d7a644);
#
#
#
#         marker_307b47d550852e62bdd6512b58f8210c.bindPopup(popup_de0b3d960422969a357ff70c2e42b8c4)
#         ;
#
#
#
#
#             marker_307b47d550852e62bdd6512b58f8210c.bindTooltip(
#                 `&lt;div&gt;
#                      NORTH SHORE, CALIFORNIA
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_307b47d550852e62bdd6512b58f8210c.setIcon(icon_61ab8305c074ddb0725e44b04352b66c);
#
#
#             var marker_0ee17def0d0e26401cf100bcdeaa6a3b = L.marker(
#                 [33.257777777777775, -115.94833333333334],
#                 {
# }
#             ).addTo(map_e884a79fed512ed89627d61d238b9872);
#
#
#             var icon_b4f968d9642af02be8f1357a1994787b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_cfa93e194be22bb046bcda21cf320571 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_974456991197d53a804a1528207510f4 = $(`&lt
