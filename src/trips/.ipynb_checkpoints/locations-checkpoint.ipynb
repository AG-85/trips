# %%
import pandas as pd
import pathlib
import math

# %%
appname = "trips"
home_dir = pathlib.Path.home()
bronze = home_dir / "data" / "bronze" / appname
silver = home_dir / "data" / "silver" / appname
gold = home_dir / "data" / "gold" / appname

bronze.mkdir(parents=True, exist_ok=True)
silver.mkdir(parents=True, exist_ok=True)
gold.mkdir(parents=True, exist_ok=True)

# %%
poi = pd.read_csv("/Users/ambikha/PycharmProjects/trips/data/poi.csv")
poi.head()
# Out:
#                       name  latitude_radian  longitude_radian  num_links  \
# 0  YAYCHI, WEST AZERBAIJAN         0.683175          0.778053         13
# 1      MOUNT FISKE GLACIER         0.648196         -2.071114          9
# 2                  ALATONA         0.258356         -0.103606         10
# 3             PEMBA ISLAND        -0.090175          0.694350         43
# 4                    MBOLO         0.149517          0.359829          6
#
#                                                links  num_categories  \
# 0  Baba Jik Rural District; West Azerbaijan Provi...               1
# 1  Mount Fiske; Mount Warlow Glacier; U.S. state;...               3
# 2  Diabaly; Alatona Irrigation Project; Mali; Nio...               2
# 3  Malaysia Airlines Flight 370; Arusha; Chake Ch...               5
# 4  UTC; Sub-prefectures of the Central African Re...               2
#
#                                           categories
# 0               POPULATED PLACES IN CHALDORAN COUNTY
# 1  GLACIERS OF THE SIERRA NEVADA (U.S.); GLACIERS...
# 2  POPULATED PLACES IN SÉGOU REGION; IRRIGATION P...
# 3  PEMBA ISLAND; ISLANDS OF TANZANIA; ISLANDS OF ...
# 4      N'DÉLÉ; POPULATED PLACES IN BAMINGUI-BANGORAN

# %%
# Approximate latitude and longitude bounds for Arizona in radians
# Arizona: lat 31.3322°N to 37.0043°N, lon 109.0452°W to 114.8183°W

lat_min = math.radians(31.3322)
lat_max = math.radians(37.0043)
lon_min = math.radians(-114.8183)
lon_max = math.radians(-109.0452)



poi["latitude_degree"] = poi["latitude_radian"].apply(math.degrees)
poi["longitude_degree"] = poi["longitude_radian"].apply(math.degrees)

poi_az = poi[
    (poi["latitude_radian"] >= lat_min)
    & (poi["latitude_radian"] <= lat_max)
    & (poi["longitude_radian"] >= lon_min)
    & (poi["longitude_radian"] <= lon_max)
].head(20)

# %%
print(f"POIs in Az: {len(poi_az)} locations\n")

from IPython.display import display

poi_display = poi_az[["name", "latitude_degree", "longitude_degree"]].copy()

poi_display["latitude_degree"] = poi_display["latitude_degree"].round(5)
poi_display["longitude_degree"] = poi_display["longitude_degree"].round(5)

poi_display = poi_display.rename(
    columns={
        "name": "POI Name",
        "latitude_degree": "Latitude (deg)",
        "longitude_degree": "Longitude (deg)",
    }
)

display(
    poi_display.reset_index(drop=True).style.set_properties(
        **{
            "background-color": "#f5f5f5",
            "border": "1px solid black",
            "text-align": "left",
        }
    )
)

print("\n`First 5 POIs:")
for idx, row in poi_az.iloc[:5].iterrows():
    print(f"- {row['name']}: ({row['latitude_radian']:.5f}, {row['longitude_radian']:.5f})")
# Out:
# POIs in Az: 20 locations
# Matplotlib is building the font cache; this may take a moment.
# <style type="text/css">
td>
#     </tr>
#     <tr>
#       <th id="T_f94ab_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f94ab_row6_col0" class="data row6 col0" >PIPE SPRING NATIONAL MONUMENT</td>
#       <td id="T_f94ab_row6_col1" class="data row6 col1" >36.861940</td>
#       <td id="T_f94ab_row6_col2" class="data row6 col2" >-112.737220</td>
#     </tr>
#     <tr>
#       <th id="T_f94ab_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f94ab_row7_col0" class="data row7 col0" >MOENKOPI, ARIZONA</td>
#       <td id="T_f94ab_row7_col1" class="data row7 col1" >36.111670</td>
#       <td id="T_f94ab_row7_col2" class="data row7 col2" >-111.220830</td>
#     </tr>
#     <tr>
#       <th id="T_f94ab_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f94ab_row8_col0" class="data row8 col0" >EJIDO VALDEZ, SONORA</td>
#       <td id="T_f94ab_row8_col1" class="data row8 col1" >31.701670</td>
#       <td id="T_f94ab_row8_col2" class="data row8 col2" >-112.543060</td>
#     </tr>
#     <tr>
#       <th id="T_f94ab_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f94ab_row9_col0" class="data row9 col0" >SOMBRERO BUTTE, ARIZONA</td>
#       <td id="T_f94ab_row9_col1" class="data row9 col1" >32.726110</td>
#       <td id="T_f94ab_row9_col2" class="data row9 col2" >-110.482220</td>
#     </tr>
#     <tr>
#       <th id="T_f94ab_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f94ab_row10_col0" class="data row10 col0" >STAR VALLEY, ARIZONA</td>
#       <td id="T_f94ab_row10_col1" class="data row10 col1" >33.351110</td>
#       <td id="T_f94ab_row10_col2" class="data row10 col2" >-110.460000</td>
#     </tr>
#     <tr>
#       <th id="T_f94ab_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f94ab_row11_col0" class="data row11 col0" >ROCK HOUSE, ARIZONA</td>
#       <td id="T_f94ab_row11_col1" class="data row11 col1" >33.632780</td>
#       <td id="T_f94ab_row11_col2" class="data row11 col2" >-110.937780</td>
#     </tr>
#     <tr>
#       <th id="T_f94ab_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f94ab_row12_col0" class="data row12 col0" >GOLDEN SHORES, ARIZONA</td>
#       <td id="T_f94ab_row12_col1" class="data row12 col1" >34.781940</td>
#       <td id="T_f94ab_row12_col2" class="data row12 col2" >-114.477780</td>
#     </tr>
#     <tr>
#       <th id="T_f94ab_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f94ab_row13_col0" class="data row13 col0" >CARR PEAK</td>
#       <td id="T_f94ab_row13_col1" class="data row13 col1" >31.412880</td>
#       <td id="T_f94ab_row13_col2" class="data row13 col2" >-110.304520</td>
#     </tr>
#     <tr>
#       <th id="T_f94ab_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f94ab_row14_col0" class="data row14 col0" >HUNTER CREEK RANCH, ARIZONA</td>
#       <td id="T_f94ab_row14_col1" class="data row14 col1" >32.829440</td>
#       <td id="T_f94ab_row14_col2" class="data row14 col2" >-109.683330</td>
#     </tr>
#     <tr>
#       <th id="T_f94ab_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f94ab_row15_col0" class="data row15 col0" >SANTA MARIA MOUNTAINS</td>
#       <td id="T_f94ab_row15_col1" class="data row15 col1" >34.835300</td>
#       <td id="T_f94ab_row15_col2" class="data row15 col2" >-112.918520</td>
#     </tr>
#     <tr>
#       <th id="T_f94ab_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f94ab_row16_col0" class="data row16 col0" >AJO PEAK</td>
#       <td id="T_f94ab_row16_col1" class="data row16 col1" >32.335610</td>
#       <td id="T_f94ab_row16_col2" class="data row16 col2" >-112.906550</td>
#     </tr>
#     <tr>
#       <th id="T_f94ab_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f94ab_row17_col0" class="data row17 col0" >KINNEY JUNCTION, ARIZONA</td>
#       <td id="T_f94ab_row17_col1" class="data row17 col1" >33.917220</td>
#       <td id="T_f94ab_row17_col2" class="data row17 col2" >-109.773890</td>
#     </tr>
#     <tr>
#       <th id="T_f94ab_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f94ab_row18_col0" class="data row18 col0" >UBANK PLACE, ARIZONA</td>
#       <td id="T_f94ab_row18_col1" class="data row18 col1" >34.910830</td>
#       <td id="T_f94ab_row18_col2" class="data row18 col2" >-109.951390</td>
#     </tr>
#     <tr>
#       <th id="T_f94ab_level0_row19"
# `First 5 POIs:
# - QUINLIN, ARIZONA: (0.56298, -1.94790)
# - CALVA, ARIZONA: (0.57911, -1.92312)
# - UNITED STATES POST OFFICE (PHOENIX, ARIZONA): (0.58389, -1.95607)
# - SOUTH BISBEE, ARIZONA: (0.54833, -1.91818)
# - BROPHY COLLEGE CHAPEL: (0.58477, -1.95602)

# %%
import folium

m = folium.Map(location=[34.0, -111.5], zoom_start=6)

# Add a marker for each POI using degree columns
for idx, row in poi_az.iterrows():
    lat = row["latitude_degree"]
    lon = row["longitude_degree"]
    name = row["name"]

    folium.Marker(
        location=[lat, lon],
        popup=name,
        tooltip=name,
        icon=folium.Icon(color="blue", icon="info-sign"),
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_13c6f6cf66fedea206236faee9ba9b63 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_13c6f6cf66fedea206236faee9ba9b63&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_13c6f6cf66fedea206236faee9ba9b63 = L.map(
#                 &quot;map_13c6f6cf66fedea206236faee9ba9b63&quot;,
#                 {
#                     center: [34.0, -111.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_36cfda7f29efb2c55939316f86bbcae2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_36cfda7f29efb2c55939316f86bbcae2.addTo(map_13c6f6cf66fedea206236faee9ba9b63);
#
#
#             var marker_36b215bc88702dc7c0072118d150add7 = L.marker(
#                 [32.25611111111111, -111.60638888888889],
#                 {
# }
#             ).addTo(map_13c6f6cf66fedea206236faee9ba9b63);
#
#
#             var icon_ce16722da047cf8da9f4db49ddb27cf6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_479f10a727dcfcb66353435758d5a90e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5bea9cecdf2fd66e97dc334308efa831 = $(`&lt;div id=&quot;html_5bea9cecdf2fd66e97dc334308efa831&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;QUINLIN, ARIZONA&lt;/div&gt;`)[0];
#                 popup_479f10a727dcfcb66353435758d5a90e.setContent(html_5bea9cecdf2fd66e97dc334308efa831);
#
#
#
#         marker_36b215bc88702dc7c0072118d150add7.bindPopup(popup_479f10a727dcfcb66353435758d5a90e)
#         ;
#
#
#
#
#             marker_36b215bc88702dc7c0072118d150add7.bindTooltip(
#                 `&lt;div&gt;
#                      QUINLIN, ARIZONA
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_36b215bc88702dc7c0072118d150add7.setIcon(icon_ce16722da047cf8da9f4db49ddb27cf6);
#
#
#             var marker_e41732b3868c4ec1966bdc566f52ab6c = L.marker(
#                 [33.18055555555555, -110.1863888888889],
#                 {
# }
#             ).addTo(map_13c6f6cf66fedea206236faee9ba9b63);
#
#
#             var icon_6bf502c052dabc23332e6711e451f864 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_fe088b293f528de338ee6661f5bce295 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1607886690cf5aa5747bb4e9770ddd67 = $(`&lt;div id=&quot;html_1607886690cf5aa5747bb4e9770ddd67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CALVA, ARIZONA&lt;/div&gt;`)[0];
#                 popup_fe088b293f528de338ee6661f5bce295.setContent(html_1607886690cf5aa5747bb4e9770ddd67);
#
#
#
#         marker_e41732b3868c4ec1966bdc566f52ab6c.bindPopup(popup_fe088b293f528de338ee6661f5bce295)
#         ;
#
#
#
#
#             marker_e41732b3868c4ec1966bdc566f52ab6c.bindTooltip(
#                 `&lt;div&gt;
#                      CALVA, ARIZONA
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_e41732b3868c4ec1966bdc566f52ab6c.setIcon(icon_6bf502c052dabc23332e6711e451f864);
#
#
#             var marker_feba5331935c2c914bc32edc69b4fdbd = L.marker(
#                 [33.45444444444445, -112.07444444444442],
#                 {
# }
#             ).addTo(map_13c6f6cf66fedea206236faee9ba9b63);
#
#
#             var icon_b06e1a930425499d4aca963d82d65186 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_aa1189513a47d17dbadb828e601eb891 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb6ca96e7c22ecc6f53949db1ccd98be = $(`&lt;div id=&quot;html_cb6ca96e7c22ecc6f5
